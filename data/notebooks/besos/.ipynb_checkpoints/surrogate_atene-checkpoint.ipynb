# %% [markdown]
# # Surrogate Modelling on BESOS
#
# Surrogate modelling or metamodelling is a way to emulate physics-based building simulation models [[1]].
#
# BESOS integrates building simulation and surrogate modelling using:
# + EnergyPlus model editing and execution via EPPy using [Evaluators](../Evaluators/Evaluators.ipynb)
# + [sampling toolboxes](https://pythonhosted.org/pyDOE/)
# + machine learning toolboxes like [ScikitLearn](https://scikit-learn.org/stable/) and [TensorFlow](https://www.tensorflow.org/)
# + the `besos` module to simplify the interconnection of the above items.
#
# [1]: https://www.sciencedirect.com/science/article/pii/S0378778819302877

# %% [markdown]
# ## Surrogate Modelling workflow
#
# The figure below shows a BESOS workflow that covers all the elements needed to derive surrogate models.
# This is supported by access to powerful hardware for conducting sampling and model training quickly in parallel.

# %% [markdown]
# <img src="./besos_surrogate_overview.png" alt="BESOS for Surrogate Modelling"
# title="BESOS for Surrogate Modelling" width="800" />
#
# _BESOS workflow for Surrogate Modelling [[1]]._
#
# [1]: https://www.sciencedirect.com/science/article/pii/S0378778819302877.

# %% [markdown]
# # Interactive Surrogate Modelling
#
# + define a problem consisting of parameters to vary with ranges and an objective function
# + sample the problem space
# + define an Evaluator by linking the problem to an EnergyPlus model
# + run the Evaluator for the samples
# + train a surrogate model over the samples
# + explore the design space using an interactive plot that queries the surrogate model

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from besos import eppy_funcs as ef, sampling
from besos.evaluator import EvaluatorEP,EvaluatorGeneric
from besos.parameters import FieldSelector, Parameter, RangeParameter, expand_plist,wwr, FilterSelector, CategoryParameter, GenericSelector,expand_plist 
from besos.problem import EPProblem,Problem
from ipywidgets import FloatSlider, interact
from matplotlib import pyplot as plt
from sklearn import linear_model, pipeline
from sklearn.preprocessing import StandardScaler
# %matplotlib notebook

# %% [markdown]
# ## Building model
# Next we load an EnergyPlus model. The example is a small office, or we could pass in the IDF filename.

# %%
building = ef.get_building('test_new_eng.idf')
building.idfobjects
# Out:
# {'VERSION': [
#  Version,
#      9.6;                      !- Version Identifier
#  ],
#  'SIMULATIONCONTROL': [
#  SimulationControl,
#      Yes,                      !- Do Zone Sizing Calculation
#      Yes,                      !- Do System Sizing Calculation
#      No,                       !- Do Plant Sizing Calculation
#      No,                       !- Run Simulation for Sizing Periods
#      Yes,                      !- Run Simulation for Weather File Run Periods
#      No,                       !- Do HVAC Sizing Simulation for Sizing Periods
#      1;                        !- Maximum Number of HVAC Sizing Simulation Passes
#  ],
#  'PERFORMANCEPRECISIONTRADEOFFS': [],
#  'BUILDING': [
#  Building,
#      Building,                 !- Name
#      0,                        !- North Axis
#      Suburbs,                  !- Terrain
#      0.04,                     !- Loads Convergence Tolerance Value
#      0.4,                      !- Temperature Convergence Tolerance Value
#      FullExterior,             !- Solar Distribution
#      25,                       !- Maximum Number of Warmup Days
#      6;                        !- Minimum Number of Warmup Days
#  ],
#  'SHADOWCALCULATION': [
#  ShadowCalculation,
#      PolygonClipping,          !- Shading Calculation Method
#      Periodic,                 !- Shading Calculation Update Frequency Method
#      20,                       !- Shading Calculation Update Frequency
#      15000,                    !- Maximum Figures in Shadow Overlap Calculations
#      SutherlandHodgman;        !- Polygon Clipping Algorithm
#  ],
#  'SURFACECONVECTIONALGORITHM:INSIDE': [
#  SurfaceConvectionAlgorithm:Inside,
#      TARP;                     !- Algorithm
#  ],
#  'SURFACECONVECTIONALGORITHM:OUTSIDE': [
#  SurfaceConvectionAlgorithm:Outside,
#      DOE-2;                    !- Algorithm
#  ],
#  'HEATBALANCEALGORITHM': [
#  HeatBalanceAlgorithm,
#      ConductionTransferFunction,    !- Algorithm
#      2000,                     !- Surface Temperature Upper Limit
#      0.00000001,               !- Minimum Surface Convection Heat Transfer Coefficient Value
#      1000;                     !- Maximum Surface Convection Heat Transfer Coefficient Value
#  ],
#  'HEATBALANCESETTINGS:CONDUCTIONFINITEDIFFERENCE': [],
#  'ZONEAIRHEATBALANCEALGORITHM': [],
#  'ZONEAIRCONTAMINANTBALANCE': [],
#  'ZONEAIRMASSFLOWCONSERVATION': [],
#  'ZONECAPACITANCEMULTIPLIER:RESEARCHSPECIAL': [
#  ZoneCapacitanceMultiplier:ResearchSpecial,
#      All,                      !- Name
#      ,                         !- Zone or ZoneList Name
#      1,                        !- Temperature Capacity Multiplier
#      1,                        !- Humidity Capacity Multiplier
#      1,                        !- Carbon Dioxide Capacity Multiplier
#      1;                        !- Generic Contaminant Capacity Multiplier
#  ],
#  'TIMESTEP': [
#  Timestep,
#      2;                        !- Number of Timesteps per Hour
#  ],
#  'CONVERGENCELIMITS': [
#  ConvergenceLimits,
#      1,                        !- Minimum System Timestep
#      25;                       !- Maximum HVAC Iterations
#  ],
#  'HVACSYSTEMROOTFINDINGALGORITHM': [],
#  'COMPLIANCE:BUILDING': [],
#  'SITE:LOCATION': [
#  Site:Location,
#      Turin,                    !- Name
#      45.22,                    !- Latitude
#      7.65,                     !- Longitude
#      1,                        !- Time Zone
#      287;                      !- Elevation
#  ],
#  'SITE:VARIABLELOCATION': [],
#  'SIZINGPERIOD:DESIGNDAY': [
#  SizingPeriod:DesignDay,
#      Summer Design Day Lug,    !- Name
#      7,                        !- Month
#      15,                       !- Day of Month
#      SummerDesignDay,          !- Day Type
#      30.9,                     !- Maximum DryBulb Temperature
#      10,                       !- Daily DryBulb Temperature Range
#      ,                         !- DryBulb Temperature Range Modifier Type
#      ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#      WetBulb,                  !- Humidity Condition Type
#      22.3,                     !- Wetbulb or DewPoint at Maximum DryBulb
#      ,                         !- Humidity Condition Day Schedule Name
#      ,                         !- Humidity Ratio at Maximum DryBulb
#      ,                         !- Enthalpy at Maximum DryBulb
#      ,                         !- Daily WetBulb Temperature Range
#      97924.4,                  !- Barometric Pressure
#      0,                        !- Wind Speed
#      0,                        !- Wind Direction
#      No,                       !- Rain Indicator
#      No,                       !- Snow Indicator
#      Yes,                      !- Daylight Saving Time Indicator
#      ASHRAEClearSky,           !- Solar Model Indicator
#      ,                         !- Beam Solar Day Schedule Name
#      ,                         !- Diffuse Solar Day Schedule Name
#      ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#      ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#      0.98;                     !- Sky Clearness
#  ,
#  SizingPeriod:DesignDay,
#      Winter Design Day,        !- Name
#      1,                        !- Month
#      15,                       !- Day of Month
#      WinterDesignDay,          !- Day Type
#      -5.9,                     !- Maximum DryBulb Temperature
#      0,                        !- Daily DryBulb Temperature Range
#      ,                         !- DryBulb Temperature Range Modifier Type
#      ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#      WetBulb,                  !- Humidity Condition Type
#      -5.9,                     !- Wetbulb or DewPoint at Maximum DryBulb
#      ,                         !- Humidity Condition Day Schedule Name
#      ,                         !- Humidity Ratio at Maximum DryBulb
#      ,                         !- Enthalpy at Maximum DryBulb
#      ,                         !- Daily WetBulb Temperature Range
#      97924.4,                  !- Barometric Pressure
#      8.5,                      !- Wind Speed
#      0,                        !- Wind Direction
#      No,                       !- Rain Indicator
#      No,                       !- Snow Indicator
#      No,                       !- Daylight Saving Time Indicator
#      ,                         !- Solar Model Indicator
#      ,                         !- Beam Solar Day Schedule Name
#      ,                         !- Diffuse Solar Day Schedule Name
#      ,                         !- ASHRAE Clear Sky Optical Depth for Beam Irradiance taub
#      ,                         !- ASHRAE Clear Sky Optical Depth for Diffuse Irradiance taud
#      0;                        !- Sky Clearness
#  ],
#  'SIZINGPERIOD:WEATHERFILEDAYS': [],
#  'SIZINGPERIOD:WEATHERFILECONDITIONTYPE': [],
#  'RUNPERIOD': [
#  RunPeriod,
#      Year_simulation,          !- Name
#      1,                        !- Begin Month
#      1,                        !- Begin Day of Month
#      ,                         !- Begin Year
#      12,                       !- End Month
#      31,                       !- End Day of Month
#      ,                         !- End Year
#      ,                         !- Day of Week for Start Day
#      No,                       !- Use Weather File Holidays and Special Days
#      No,                       !- Use Weather File Daylight Saving Period
#      Yes,                      !- Apply Weekend Holiday Rule
#      Yes,                      !- Use Weather File Rain Indicators
#      Yes;                      !- Use Weather File Snow Indicators
#  ],
#  'RUNPERIODCONTROL:SPECIALDAYS': [],
#  'RUNPERIODCONTROL:DAYLIGHTSAVINGTIME': [
#  RunPeriodControl:DaylightSavingTime,
#      Last Sunday in March,     !- Start Date
#      Last Sunday in October;    !- End Date
#  ],
#  'WEATHERPROPERTY:SKYTEMPERATURE': [],
#  'SITE:WEATHERSTATION': [],
#  'SITE:HEIGHTVARIATION': [],
#  'SITE:GROUNDTEMPERATURE:BUILDINGSURFACE': [
#  Site:GroundTemperature:BuildingSurface,
#      18,                       !- January Ground Temperature
#      18,                       !- February Ground Temperature
#      18,                       !- March Ground Temperature
#      18,                       !- April Ground Temperature
#      18,                       !- May Ground Temperature
#      18,                       !- June Ground Temperature
#      18,                       !- July Ground Temperature
#      18,                       !- August Ground Temperature
#      18,                       !- September Ground Temperature
#      18,                       !- October Ground Temperature
#      18,                       !- November Ground Temperature
#      18;                       !- December Ground Temperature
#  ],
#  'SITE:GROUNDTEMPERATURE:FCFACTORMETHOD': [
#  Site:GroundTemperature:FCfactorMethod,
#      1.99,                     !- January Ground Temperature
#      1.11,                     !- February Ground Temperature
#      2.67,                     !- March Ground Temperature
#      5.12,                     !- April Ground Temperature
#      11.52,                    !- May Ground Temperature
#      16.46,                    !- June Ground Temperature
#      19.79,                    !- July Ground Temperature
#      20.81,                    !- August Ground Temperature
#      19.08,                    !- September Ground Temperature
#      15.24,                    !- October Ground Temperature
#      10.12,                    !- November Ground Temperature
#      5.36;                     !- December Ground Temperature
#  ],
#  'SITE:GROUNDTEMPERATURE:SHALLOW': [
#  Site:GroundTemperature:Shallow,
#      14,                       !- January Surface Ground Temperature
#      14,                       !- February Surface Ground Temperature
#      14,                       !- March Surface Ground Temperature
#      14,                       !- April Surface Ground Temperature
#      14,                       !- May Surface Ground Temperature
#      14,                       !- June Surface Ground Temperature
#      14,                       !- July Surface Ground Temperature
#      14,                       !- August Surface Ground Temperature
#      14,                       !- September Surface Ground Temperature
#      14,                       !- October Surface Ground Temperature
#      14,                       !- November Surface Ground Temperature
#      14;                       !- December Surface Ground Temperature
#  ],
#  'SITE:GROUNDTEMPERATURE:DEEP': [
#  Site:GroundTemperature:Deep,
#      14,                       !- January Deep Ground Temperature
#      14,                       !- February Deep Ground Temperature
#      14,                       !- March Deep Ground Temperature
#      14,                       !- April Deep Ground Temperature
#      14,                       !- May Deep Ground Temperature
#      14,                       !- June Deep Ground Temperature
#      14,                       !- July Deep Ground Temperature
#      14,                       !- August Deep Ground Temperature
#      14,                       !- September Deep Ground Temperature
#      14,                       !- October Deep Ground Temperature
#      14,                       !- November Deep Ground Temperature
#      14;                       !- December Deep Ground Temperature
#  ],
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:FINITEDIFFERENCE': [],
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:KUSUDAACHENBACH': [],
#  'SITE:GROUNDTEMPERATURE:UNDISTURBED:XING': [],
#  'SITE:GROUNDDOMAIN:SLAB': [],
#  'SITE:GROUNDDOMAIN:BASEMENT': [],
#  'SITE:GROUNDREFLECTANCE': [
#  Site:GroundReflectance,
#      0.2,                      !- January Ground Reflectance
#      0.2,                      !- February Ground Reflectance
#      0.2,                      !- March Ground Reflectance
#      0.2,                      !- April Ground Reflectance
#      0.2,                      !- May Ground Reflectance
#      0.2,                      !- June Ground Reflectance
#      0.2,                      !- July Ground Reflectance
#      0.2,                      !- August Ground Reflectance
#      0.2,                      !- September Ground Reflectance
#      0.2,                      !- October Ground Reflectance
#      0.2,                      !- November Ground Reflectance
#      0.2;                      !- December Ground Reflectance
#  ],
#  'SITE:GROUNDREFLECTANCE:SNOWMODIFIER': [
#  Site:GroundReflectance:SnowModifier,
#      2.0,                      !- Ground Reflected Solar Modifier
#      2.0;                      !- Daylighting Ground Reflected Solar Modifier
#  ],
#  'SITE:WATERMAINSTEMPERATURE': [],
#  'SITE:PRECIPITATION': [],
#  'ROOFIRRIGATION': [],
#  'SITE:SOLARANDVISIBLESPECTRUM': [],
#  'SITE:SPECTRUMDATA': [],
#  'SCHEDULETYPELIMITS': [
#  ScheduleTypeLimits,
#      Any Number;               !- Name
#  ,
#  ScheduleTypeLimits,
#      Fraction,                 !- Name
#      0.0,                      !- Lower Limit Value
#      1.0,                      !- Upper Limit Value
#      CONTINUOUS;               !- Numeric Type
#  ,
#  ScheduleTypeLimits,
#      Temperature,              !- Name
#      -60,                      !- Lower Limit Value
#      200,                      !- Upper Limit Value
#      CONTINUOUS;               !- Numeric Type
#  ,
#  ScheduleTypeLimits,
#      Control Type,             !- Name
#      0,                        !- Lower Limit Value
#      4,                        !- Upper Limit Value
#      DISCRETE;                 !- Numeric Type
#  ,
#  ScheduleTypeLimits,
#      On/Off,                   !- Name
#      0,                        !- Lower Limit Value
#      1,                        !- Upper Limit Value
#      DISCRETE;                 !- Numeric Type
#  ],
#  'SCHEDULE:DAY:HOURLY': [
#  Schedule:Day:Hourly,
#      0,                        !- Name
#      Any Number,               !- Schedule Type Limits Name
#      0,                        !- Hour 1
#      0,                        !- Hour 2
#      0,                        !- Hour 3
#      0,                        !- Hour 4
#      0,                        !- Hour 5
#      0,                        !- Hour 6
#      0,                        !- Hour 7
#      0,                        !- Hour 8
#      0,                        !- Hour 9
#      0,                        !- Hour 10
#      0,                        !- Hour 11
#      0,                        !- Hour 12
#      0,                        !- Hour 13
#      0,                        !- Hour 14
#      0,                        !- Hour 15
#      0,                        !- Hour 16
#      0,                        !- Hour 17
#      0,                        !- Hour 18
#      0,                        !- Hour 19
#      0,                        !- Hour 20
#      0,                        !- Hour 21
#      0,                        !- Hour 22
#      0,                        !- Hour 23
#      0;                        !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      50,                       !- Name
#      Any Number,               !- Schedule Type Limits Name
#      50,                       !- Hour 1
#      50,                       !- Hour 2
#      50,                       !- Hour 3
#      50,                       !- Hour 4
#      50,                       !- Hour 5
#      50,                       !- Hour 6
#      50,                       !- Hour 7
#      50,                       !- Hour 8
#      50,                       !- Hour 9
#      50,                       !- Hour 10
#      50,                       !- Hour 11
#      50,                       !- Hour 12
#      50,                       !- Hour 13
#      50,                       !- Hour 14
#      50,                       !- Hour 15
#      50,                       !- Hour 16
#      50,                       !- Hour 17
#      50,                       !- Hour 18
#      50,                       !- Hour 19
#      50,                       !- Hour 20
#      50,                       !- Hour 21
#      50,                       !- Hour 22
#      50,                       !- Hour 23
#      50;                       !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      Off,                      !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      0,                        !- Hour 1
#      0,                        !- Hour 2
#      0,                        !- Hour 3
#      0,                        !- Hour 4
#      0,                        !- Hour 5
#      0,                        !- Hour 6
#      0,                        !- Hour 7
#      0,                        !- Hour 8
#      0,                        !- Hour 9
#      0,                        !- Hour 10
#      0,                        !- Hour 11
#      0,                        !- Hour 12
#      0,                        !- Hour 13
#      0,                        !- Hour 14
#      0,                        !- Hour 15
#      0,                        !- Hour 16
#      0,                        !- Hour 17
#      0,                        !- Hour 18
#      0,                        !- Hour 19
#      0,                        !- Hour 20
#      0,                        !- Hour 21
#      0,                        !- Hour 22
#      0,                        !- Hour 23
#      0;                        !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      Summer Control Type Day Sch,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      4,                        !- Hour 1
#      4,                        !- Hour 2
#      4,                        !- Hour 3
#      4,                        !- Hour 4
#      4,                        !- Hour 5
#      4,                        !- Hour 6
#      4,                        !- Hour 7
#      4,                        !- Hour 8
#      4,                        !- Hour 9
#      4,                        !- Hour 10
#      4,                        !- Hour 11
#      4,                        !- Hour 12
#      4,                        !- Hour 13
#      4,                        !- Hour 14
#      4,                        !- Hour 15
#      4,                        !- Hour 16
#      4,                        !- Hour 17
#      4,                        !- Hour 18
#      4,                        !- Hour 19
#      4,                        !- Hour 20
#      4,                        !- Hour 21
#      4,                        !- Hour 22
#      4,                        !- Hour 23
#      4;                        !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      Winter Control Type Day Sch,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      4,                        !- Hour 1
#      4,                        !- Hour 2
#      4,                        !- Hour 3
#      4,                        !- Hour 4
#      4,                        !- Hour 5
#      4,                        !- Hour 6
#      4,                        !- Hour 7
#      4,                        !- Hour 8
#      4,                        !- Hour 9
#      4,                        !- Hour 10
#      4,                        !- Hour 11
#      4,                        !- Hour 12
#      4,                        !- Hour 13
#      4,                        !- Hour 14
#      4,                        !- Hour 15
#      4,                        !- Hour 16
#      4,                        !- Hour 17
#      4,                        !- Hour 18
#      4,                        !- Hour 19
#      4,                        !- Hour 20
#      4,                        !- Hour 21
#      4,                        !- Hour 22
#      4,                        !- Hour 23
#      4;                        !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      Summer Control Type Day Sch - cool,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      2,                        !- Hour 1
#      2,                        !- Hour 2
#      2,                        !- Hour 3
#      2,                        !- Hour 4
#      2,                        !- Hour 5
#      2,                        !- Hour 6
#      2,                        !- Hour 7
#      2,                        !- Hour 8
#      2,                        !- Hour 9
#      2,                        !- Hour 10
#      2,                        !- Hour 11
#      2,                        !- Hour 12
#      2,                        !- Hour 13
#      2,                        !- Hour 14
#      2,                        !- Hour 15
#      2,                        !- Hour 16
#      2,                        !- Hour 17
#      2,                        !- Hour 18
#      2,                        !- Hour 19
#      2,                        !- Hour 20
#      2,                        !- Hour 21
#      2,                        !- Hour 22
#      2,                        !- Hour 23
#      2;                        !- Hour 24
#  ,
#  Schedule:Day:Hourly,
#      Winter Control Type Day Sch - heat,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      1,                        !- Hour 1
#      1,                        !- Hour 2
#      1,                        !- Hour 3
#      1,                        !- Hour 4
#      1,                        !- Hour 5
#      1,                        !- Hour 6
#      1,                        !- Hour 7
#      1,                        !- Hour 8
#      1,                        !- Hour 9
#      1,                        !- Hour 10
#      1,                        !- Hour 11
#      1,                        !- Hour 12
#      1,                        !- Hour 13
#      1,                        !- Hour 14
#      1,                        !- Hour 15
#      1,                        !- Hour 16
#      1,                        !- Hour 17
#      1,                        !- Hour 18
#      1,                        !- Hour 19
#      1,                        !- Hour 20
#      1,                        !- Hour 21
#      1,                        !- Hour 22
#      1,                        !- Hour 23
#      1;                        !- Hour 24
#  ],
#  'SCHEDULE:DAY:INTERVAL': [],
#  'SCHEDULE:DAY:LIST': [],
#  'SCHEDULE:WEEK:DAILY': [
#  Schedule:Week:Daily,
#      Off,                      !- Name
#      Off,                      !- Sunday ScheduleDay Name
#      Off,                      !- Monday ScheduleDay Name
#      Off,                      !- Tuesday ScheduleDay Name
#      Off,                      !- Wednesday ScheduleDay Name
#      Off,                      !- Thursday ScheduleDay Name
#      Off,                      !- Friday ScheduleDay Name
#      Off,                      !- Saturday ScheduleDay Name
#      Off,                      !- Holiday ScheduleDay Name
#      Off,                      !- SummerDesignDay ScheduleDay Name
#      Off,                      !- WinterDesignDay ScheduleDay Name
#      Off,                      !- CustomDay1 ScheduleDay Name
#      Off;                      !- CustomDay2 ScheduleDay Name
#  ,
#  Schedule:Week:Daily,
#      Summer Control Type Week Sch,    !- Name
#      Summer Control Type Day Sch,    !- Sunday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Monday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Tuesday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Wednesday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Thursday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Friday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Saturday ScheduleDay Name
#      Summer Control Type Day Sch,    !- Holiday ScheduleDay Name
#      Summer Control Type Day Sch,    !- SummerDesignDay ScheduleDay Name
#      Summer Control Type Day Sch,    !- WinterDesignDay ScheduleDay Name
#      Summer Control Type Day Sch,    !- CustomDay1 ScheduleDay Name
#      Summer Control Type Day Sch;    !- CustomDay2 ScheduleDay Name
#  ,
#  Schedule:Week:Daily,
#      Winter Control Type Week Sch,    !- Name
#      Winter Control Type Day Sch,    !- Sunday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Monday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Tuesday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Wednesday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Thursday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Friday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Saturday ScheduleDay Name
#      Winter Control Type Day Sch,    !- Holiday ScheduleDay Name
#      Winter Control Type Day Sch,    !- SummerDesignDay ScheduleDay Name
#      Winter Control Type Day Sch,    !- WinterDesignDay ScheduleDay Name
#      Winter Control Type Day Sch,    !- CustomDay1 ScheduleDay Name
#      Winter Control Type Day Sch;    !- CustomDay2 ScheduleDay Name
#  ,
#  Schedule:Week:Daily,
#      Summer Control Type Week Sch - cool,    !- Name
#      Summer Control Type Day Sch - cool,    !- Sunday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Monday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Tuesday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Wednesday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Thursday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Friday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Saturday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- Holiday ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- SummerDesignDay ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- WinterDesignDay ScheduleDay Name
#      Summer Control Type Day Sch - cool,    !- CustomDay1 ScheduleDay Name
#      Summer Control Type Day Sch - cool;    !- CustomDay2 ScheduleDay Name
#  ,
#  Schedule:Week:Daily,
#      Winter Control Type Week Sch - heat,    !- Name
#      Winter Control Type Day Sch - heat,    !- Sunday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Monday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Tuesday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Wednesday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Thursday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Friday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Saturday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- Holiday ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- SummerDesignDay ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- WinterDesignDay ScheduleDay Name
#      Winter Control Type Day Sch - heat,    !- CustomDay1 ScheduleDay Name
#      Winter Control Type Day Sch - heat;    !- CustomDay2 ScheduleDay Name
#  ],
#  'SCHEDULE:WEEK:COMPACT': [],
#  'SCHEDULE:YEAR': [
#  Schedule:Year,
#      Zone Control Type Sched,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      Winter Control Type Week Sch,    !- ScheduleWeek Name 1
#      1,                        !- Start Month 1
#      1,                        !- Start Day 1
#      3,                        !- End Month 1
#      31,                       !- End Day 1
#      Summer Control Type Week Sch,    !- ScheduleWeek Name 2
#      4,                        !- Start Month 2
#      1,                        !- Start Day 2
#      9,                        !- End Month 2
#      30,                       !- End Day 2
#      Winter Control Type Week Sch,    !- ScheduleWeek Name 3
#      10,                       !- Start Month 3
#      1,                        !- Start Day 3
#      12,                       !- End Month 3
#      31;                       !- End Day 3
#  ],
#  'SCHEDULE:COMPACT': [
#  Schedule:Compact,
#      On,                       !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      1;                        !- Field 4
#  ,
#  Schedule:Compact,
#      Off,                      !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      0;                        !- Field 4
#  ,
#  Schedule:Compact,
#      Work efficiency,          !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      0;                        !- Field 4
#  ,
#  Schedule:Compact,
#      OpaqueShade,              !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      0;                        !- Field 4
#  ,
#  Schedule:Compact,
#      Zone Comfort Control Type Sched,    !- Name
#      Control Type,             !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      4;                        !- Field 4
#  ,
#  Schedule:Compact,
#      Design Days Only,         !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: SummerDesignDay WinterDesignDay,    !- Field 2
#      Until: 24:00,             !- Field 3
#      1,                        !- Field 4
#      For: AllOtherDays,        !- Field 5
#      Until: 24:00,             !- Field 6
#      0;                        !- Field 7
#  ,
#  Schedule:Compact,
#      TypOperativeTempControlSch,    !- Name
#      Temperature,              !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: SummerDesignDay WinterDesignDay,    !- Field 2
#      Until: 24:00,             !- Field 3
#      0.0,                      !- Field 4
#      For: AllOtherDays,        !- Field 5
#      Until: 24:00,             !- Field 6
#      0.5;                      !- Field 7
#  ,
#  Schedule:Compact,
#      OnWinterDesignDay,        !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: WinterDesignDay,     !- Field 2
#      Until: 24:00,             !- Field 3
#      1,                        !- Field 4
#      For: AllOtherDays,        !- Field 5
#      Until: 24:00,             !- Field 6
#      0;                        !- Field 7
#  ,
#  Schedule:Compact,
#      OnSummerDesignDay,        !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: SummerDesignDay,     !- Field 2
#      Until: 24:00,             !- Field 3
#      1,                        !- Field 4
#      For: AllOtherDays,        !- Field 5
#      Until: 24:00,             !- Field 6
#      0;                        !- Field 7
#  ,
#  Schedule:Compact,
#      AirVelocitySchedule,      !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      .137;                     !- Field 4
#  ,
#  Schedule:Compact,
#      On 24/7,                  !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      1;                        !- Field 4
#  ,
#  Schedule:Compact,
#      Summer (Northern Hemisphere),    !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Mar,          !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      0,                        !- Field 4
#      Through: 30 Sep,          !- Field 5
#      For: AllDays,             !- Field 6
#      Until: 24:00,             !- Field 7
#      1,                        !- Field 8
#      Through: 31 Dec,          !- Field 9
#      For: AllDays,             !- Field 10
#      Until: 24:00,             !- Field 11
#      0;                        !- Field 12
#  ,
#  Schedule:Compact,
#      Dwell_DomToilet_Occ,      !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 06:00,             !- Field 3
#      0,                        !- Field 4
#      Until: 07:00,             !- Field 5
#      0.25,                     !- Field 6
#      Until: 09:00,             !- Field 7
#      1,                        !- Field 8
#      Until: 10:00,             !- Field 9
#      0.25,                     !- Field 10
#      Until: 18:00,             !- Field 11
#      0,                        !- Field 12
#      Until: 19:00,             !- Field 13
#      0.5,                      !- Field 14
#      Until: 21:00,             !- Field 15
#      1,                        !- Field 16
#      Until: 22:00,             !- Field 17
#      0.3,                      !- Field 18
#      Until: 24:00,             !- Field 19
#      0,                        !- Field 20
#      For: Weekends,            !- Field 21
#      Until: 06:00,             !- Field 22
#      0,                        !- Field 23
#      Until: 07:00,             !- Field 24
#      0.25,                     !- Field 25
#      Until: 09:00,             !- Field 26
#      1,                        !- Field 27
#      Until: 10:00,             !- Field 28
#      0.25,                     !- Field 29
#      Until: 18:00,             !- Field 30
#      0,                        !- Field 31
#      Until: 19:00,             !- Field 32
#      0.5,                      !- Field 33
#      Until: 21:00,             !- Field 34
#      1,                        !- Field 35
#      Until: 22:00,             !- Field 36
#      0.3,                      !- Field 37
#      Until: 24:00,             !- Field 38
#      0,                        !- Field 39
#      For: Holidays,            !- Field 40
#      Until: 06:00,             !- Field 41
#      0,                        !- Field 42
#      Until: 07:00,             !- Field 43
#      0.25,                     !- Field 44
#      Until: 09:00,             !- Field 45
#      1,                        !- Field 46
#      Until: 10:00,             !- Field 47
#      0.25,                     !- Field 48
#      Until: 18:00,             !- Field 49
#      0,                        !- Field 50
#      Until: 19:00,             !- Field 51
#      0.5,                      !- Field 52
#      Until: 21:00,             !- Field 53
#      1,                        !- Field 54
#      Until: 22:00,             !- Field 55
#      0.3,                      !- Field 56
#      Until: 24:00,             !- Field 57
#      0,                        !- Field 58
#      For: WinterDesignDay AllOtherDays,    !- Field 59
#      Until: 24:00,             !- Field 60
#      0;                        !- Field 61
#  ,
#  Schedule:Compact,
#      Dwell_DomToilet_Light,    !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 06:00,             !- Field 3
#      0,                        !- Field 4
#      Until: 10:00,             !- Field 5
#      1,                        !- Field 6
#      Until: 18:00,             !- Field 7
#      0,                        !- Field 8
#      Until: 22:00,             !- Field 9
#      1,                        !- Field 10
#      Until: 24:00,             !- Field 11
#      0,                        !- Field 12
#      For: Weekends,            !- Field 13
#      Until: 06:00,             !- Field 14
#      0,                        !- Field 15
#      Until: 10:00,             !- Field 16
#      1,                        !- Field 17
#      Until: 18:00,             !- Field 18
#      0,                        !- Field 19
#      Until: 22:00,             !- Field 20
#      1,                        !- Field 21
#      Until: 24:00,             !- Field 22
#      0,                        !- Field 23
#      For: Holidays,            !- Field 24
#      Until: 06:00,             !- Field 25
#      0,                        !- Field 26
#      Until: 10:00,             !- Field 27
#      1,                        !- Field 28
#      Until: 18:00,             !- Field 29
#      0,                        !- Field 30
#      Until: 22:00,             !- Field 31
#      1,                        !- Field 32
#      Until: 24:00,             !- Field 33
#      0,                        !- Field 34
#      For: WinterDesignDay AllOtherDays,    !- Field 35
#      Until: 24:00,             !- Field 36
#      0;                        !- Field 37
#  ,
#  Schedule:Compact,
#      Dwell_DomToilet_Equip,    !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 07:00,             !- Field 3
#      0.06196,                  !- Field 4
#      Until: 08:00,             !- Field 5
#      0.53098,                  !- Field 6
#      Until: 09:00,             !- Field 7
#      1,                        !- Field 8
#      Until: 10:00,             !- Field 9
#      0.53098,                  !- Field 10
#      Until: 17:00,             !- Field 11
#      0.06196,                  !- Field 12
#      Until: 18:00,             !- Field 13
#      0.29647,                  !- Field 14
#      Until: 19:00,             !- Field 15
#      0.53098,                  !- Field 16
#      Until: 20:00,             !- Field 17
#      0.76549,                  !- Field 18
#      Until: 22:00,             !- Field 19
#      1,                        !- Field 20
#      Until: 23:00,             !- Field 21
#      0.76549,                  !- Field 22
#      Until: 24:00,             !- Field 23
#      0.29647,                  !- Field 24
#      For: Weekends,            !- Field 25
#      Until: 07:00,             !- Field 26
#      0.06196,                  !- Field 27
#      Until: 08:00,             !- Field 28
#      0.53098,                  !- Field 29
#      Until: 09:00,             !- Field 30
#      1,                        !- Field 31
#      Until: 10:00,             !- Field 32
#      0.53098,                  !- Field 33
#      Until: 17:00,             !- Field 34
#      0.06196,                  !- Field 35
#      Until: 18:00,             !- Field 36
#      0.29647,                  !- Field 37
#      Until: 19:00,             !- Field 38
#      0.53098,                  !- Field 39
#      Until: 20:00,             !- Field 40
#      0.76549,                  !- Field 41
#      Until: 22:00,             !- Field 42
#      1,                        !- Field 43
#      Until: 23:00,             !- Field 44
#      0.76549,                  !- Field 45
#      Until: 24:00,             !- Field 46
#      0.29647,                  !- Field 47
#      For: Holidays,            !- Field 48
#      Until: 07:00,             !- Field 49
#      0.06196,                  !- Field 50
#      Until: 08:00,             !- Field 51
#      0.53098,                  !- Field 52
#      Until: 09:00,             !- Field 53
#      1,                        !- Field 54
#      Until: 10:00,             !- Field 55
#      0.53098,                  !- Field 56
#      Until: 17:00,             !- Field 57
#      0.06196,                  !- Field 58
#      Until: 18:00,             !- Field 59
#      0.29647,                  !- Field 60
#      Until: 19:00,             !- Field 61
#      0.53098,                  !- Field 62
#      Until: 20:00,             !- Field 63
#      0.76549,                  !- Field 64
#      Until: 22:00,             !- Field 65
#      1,                        !- Field 66
#      Until: 23:00,             !- Field 67
#      0.76549,                  !- Field 68
#      Until: 24:00,             !- Field 69
#      0.29647,                  !- Field 70
#      For: WinterDesignDay AllOtherDays,    !- Field 71
#      Until: 24:00,             !- Field 72
#      0;                        !- Field 73
#  ,
#  Schedule:Compact,
#      Dwell_DomBed_Occ,         !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 07:00,             !- Field 3
#      1,                        !- Field 4
#      Until: 08:00,             !- Field 5
#      0.5,                      !- Field 6
#      Until: 09:00,             !- Field 7
#      0.25,                     !- Field 8
#      Until: 22:00,             !- Field 9
#      0,                        !- Field 10
#      Until: 23:00,             !- Field 11
#      0.25,                     !- Field 12
#      Until: 24:00,             !- Field 13
#      0.75,                     !- Field 14
#      For: Weekends,            !- Field 15
#      Until: 07:00,             !- Field 16
#      1,                        !- Field 17
#      Until: 08:00,             !- Field 18
#      0.5,                      !- Field 19
#      Until: 09:00,             !- Field 20
#      0.25,                     !- Field 21
#      Until: 22:00,             !- Field 22
#      0,                        !- Field 23
#      Until: 23:00,             !- Field 24
#      0.25,                     !- Field 25
#      Until: 24:00,             !- Field 26
#      0.75,                     !- Field 27
#      For: Holidays,            !- Field 28
#      Until: 07:00,             !- Field 29
#      1,                        !- Field 30
#      Until: 08:00,             !- Field 31
#      0.5,                      !- Field 32
#      Until: 09:00,             !- Field 33
#      0.25,                     !- Field 34
#      Until: 22:00,             !- Field 35
#      0,                        !- Field 36
#      Until: 23:00,             !- Field 37
#      0.25,                     !- Field 38
#      Until: 24:00,             !- Field 39
#      0.75,                     !- Field 40
#      For: WinterDesignDay AllOtherDays,    !- Field 41
#      Until: 24:00,             !- Field 42
#      0;                        !- Field 43
#  ,
#  Schedule:Compact,
#      Dwell_DomBed_Light,       !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 07:00,             !- Field 3
#      0,                        !- Field 4
#      Until: 10:00,             !- Field 5
#      1,                        !- Field 6
#      Until: 19:00,             !- Field 7
#      0,                        !- Field 8
#      Until: 23:00,             !- Field 9
#      0.2,                      !- Field 10
#      Until: 24:00,             !- Field 11
#      0,                        !- Field 12
#      For: Weekends,            !- Field 13
#      Until: 07:00,             !- Field 14
#      0,                        !- Field 15
#      Until: 10:00,             !- Field 16
#      1,                        !- Field 17
#      Until: 19:00,             !- Field 18
#      0,                        !- Field 19
#      Until: 23:00,             !- Field 20
#      0.2,                      !- Field 21
#      Until: 24:00,             !- Field 22
#      0,                        !- Field 23
#      For: Holidays,            !- Field 24
#      Until: 07:00,             !- Field 25
#      0,                        !- Field 26
#      Until: 10:00,             !- Field 27
#      1,                        !- Field 28
#      Until: 19:00,             !- Field 29
#      0,                        !- Field 30
#      Until: 23:00,             !- Field 31
#      0.2,                      !- Field 32
#      Until: 24:00,             !- Field 33
#      0,                        !- Field 34
#      For: WinterDesignDay AllOtherDays,    !- Field 35
#      Until: 24:00,             !- Field 36
#      0;                        !- Field 37
#  ,
#  Schedule:Compact,
#      Dwell_DomBed_Equip,       !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 07:00,             !- Field 3
#      0.06993,                  !- Field 4
#      Until: 08:00,             !- Field 5
#      0.53497,                  !- Field 6
#      Until: 09:00,             !- Field 7
#      1,                        !- Field 8
#      Until: 10:00,             !- Field 9
#      0.53497,                  !- Field 10
#      Until: 17:00,             !- Field 11
#      0.06993,                  !- Field 12
#      Until: 18:00,             !- Field 13
#      0.30245,                  !- Field 14
#      Until: 19:00,             !- Field 15
#      0.53497,                  !- Field 16
#      Until: 20:00,             !- Field 17
#      0.76748,                  !- Field 18
#      Until: 22:00,             !- Field 19
#      1,                        !- Field 20
#      Until: 23:00,             !- Field 21
#      0.76748,                  !- Field 22
#      Until: 24:00,             !- Field 23
#      0.30245,                  !- Field 24
#      For: Weekends,            !- Field 25
#      Until: 07:00,             !- Field 26
#      0.06993,                  !- Field 27
#      Until: 08:00,             !- Field 28
#      0.53497,                  !- Field 29
#      Until: 09:00,             !- Field 30
#      1,                        !- Field 31
#      Until: 10:00,             !- Field 32
#      0.53497,                  !- Field 33
#      Until: 17:00,             !- Field 34
#      0.06993,                  !- Field 35
#      Until: 18:00,             !- Field 36
#      0.30245,                  !- Field 37
#      Until: 19:00,             !- Field 38
#      0.53497,                  !- Field 39
#      Until: 20:00,             !- Field 40
#      0.76748,                  !- Field 41
#      Until: 22:00,             !- Field 42
#      1,                        !- Field 43
#      Until: 23:00,             !- Field 44
#      0.76748,                  !- Field 45
#      Until: 24:00,             !- Field 46
#      0.30245,                  !- Field 47
#      For: Holidays,            !- Field 48
#      Until: 07:00,             !- Field 49
#      0.06993,                  !- Field 50
#      Until: 08:00,             !- Field 51
#      0.53497,                  !- Field 52
#      Until: 09:00,             !- Field 53
#      1,                        !- Field 54
#      Until: 10:00,             !- Field 55
#      0.53497,                  !- Field 56
#      Until: 17:00,             !- Field 57
#      0.06993,                  !- Field 58
#      Until: 18:00,             !- Field 59
#      0.30245,                  !- Field 60
#      Until: 19:00,             !- Field 61
#      0.53497,                  !- Field 62
#      Until: 20:00,             !- Field 63
#      0.76748,                  !- Field 64
#      Until: 22:00,             !- Field 65
#      1,                        !- Field 66
#      Until: 23:00,             !- Field 67
#      0.76748,                  !- Field 68
#      Until: 24:00,             !- Field 69
#      0.30245,                  !- Field 70
#      For: WinterDesignDay AllOtherDays,    !- Field 71
#      Until: 24:00,             !- Field 72
#      0;                        !- Field 73
#  ,
#  Schedule:Compact,
#      Dwell_DomDining_Occ,      !- Name
#      Fraction,                 !- Schedule Type Limits Name
#      Through: 31 Dec,          !- Field 1
#      For: Weekdays SummerDesignDay,    !- Field 2
#      Until: 06:00,             !- Field 3
#      0,                        !- Field 4
#      Until: 07:00,             !- Field 5
#      0.25,                     !- Field 6
#      Until: 09:00,             !- Field 7
#      1,                        !- Field 8
#      Until: 10:00,             !- Field 9
#      0.25,                     !- Field 10
#      Until: 18:00,             !- Field 11
#      0,                        !- Field 12
#      Until: 19:00,             !- Field 13
#      0.5,                      !- Field 14
#      Until: 21:00,             !- Field 15
#      1,                        !- Field 16
#      Until: 22:00,             !- Field 17
#      0.3,                      !- Field 18
#      Until: 24:00,             !- Field 19
#      0,                        !- Field 20
#      For: Weekends,            !- Field 21
#      Until: 06:00,             !- Field 22
#      0,                        !- Field 23
#      Until: 07:00,             !- Field 24
#      0.25,                     !- Field 25
#      Until: 09:00,             !- Field 26
#      1,                        !- Field 27
#      Until: 10:00,             !- Field 28
#      0.25,                     !- Field 29
#      Until: 18:00,             !- Field 30
#      0,                        !- Field 31
#      Until: 19:00,             !- Field 32
#      0.5,                      !- Field 33
#      Until: 21:00,             !- Field 34
#      1,                        !- Field 35
#      Until: 22:00,             !- Field 36
#      0.3,                      !- Field 37
#      Until: 24:00,             !- Field 38
#      0,                        !- Field 39
#      For: Holidays,            !- Field 40
#      Until: 06:00,             !- Field 41
#      0,                        !- Field 42
#      Until: 07:00,             !- Field 43
# ...
#      DHW Mains Temperature Block1B:Bathroom,    !- Cold Water Supply Temperature Schedule Name
#      Block1B:Bathroom;         !- Zone Name
#  ,
#  WaterUse:Equipment,
#      DHW Block1B:Livingroom,    !- Name
#      DHW Block1B:Livingroom,    !- EndUse Subcategory
#      1.027718e-06,             !- Peak Flow Rate
#      Dwell_DomDining_Occ,      !- Flow Rate Fraction Schedule Name
#      DHW Supply Temperature Block1B:Livingroom,    !- Target Temperature Schedule Name
#      DHW Supply Temperature Block1B:Livingroom,    !- Hot Water Supply Temperature Schedule Name
#      DHW Mains Temperature Block1B:Livingroom,    !- Cold Water Supply Temperature Schedule Name
#      Block1B:Livingroom;       !- Zone Name
#  ,
#  WaterUse:Equipment,
#      DHW Block1B:Room,         !- Name
#      DHW Block1B:Room,         !- EndUse Subcategory
#      2.349010e-07,             !- Peak Flow Rate
#      Dwell_DomBed_Occ,         !- Flow Rate Fraction Schedule Name
#      DHW Supply Temperature Block1B:Room,    !- Target Temperature Schedule Name
#      DHW Supply Temperature Block1B:Room,    !- Hot Water Supply Temperature Schedule Name
#      DHW Mains Temperature Block1B:Room,    !- Cold Water Supply Temperature Schedule Name
#      Block1B:Room;             !- Zone Name
#  ],
#  'WATERUSE:CONNECTIONS': [],
#  'WATERUSE:STORAGE': [],
#  'WATERUSE:WELL': [],
#  'WATERUSE:RAINCOLLECTOR': [],
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:OUTDOORAIR': [],
#  'FAULTMODEL:HUMIDITYSENSOROFFSET:OUTDOORAIR': [],
#  'FAULTMODEL:ENTHALPYSENSOROFFSET:OUTDOORAIR': [],
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:RETURNAIR': [],
#  'FAULTMODEL:ENTHALPYSENSOROFFSET:RETURNAIR': [],
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:CHILLERSUPPLYWATER': [],
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:COILSUPPLYAIR': [],
#  'FAULTMODEL:TEMPERATURESENSOROFFSET:CONDENSERSUPPLYWATER': [],
#  'FAULTMODEL:THERMOSTATOFFSET': [],
#  'FAULTMODEL:HUMIDISTATOFFSET': [],
#  'FAULTMODEL:FOULING:AIRFILTER': [],
#  'FAULTMODEL:FOULING:BOILER': [],
#  'FAULTMODEL:FOULING:EVAPORATIVECOOLER': [],
#  'FAULTMODEL:FOULING:CHILLER': [],
#  'FAULTMODEL:FOULING:COOLINGTOWER': [],
#  'FAULTMODEL:FOULING:COIL': [],
#  'MATRIX:TWODIMENSION': [],
#  'HYBRIDMODEL:ZONE': [],
#  'CURVE:LINEAR': [],
#  'CURVE:QUADLINEAR': [],
#  'CURVE:QUINTLINEAR': [],
#  'CURVE:QUADRATIC': [],
#  'CURVE:CUBIC': [],
#  'CURVE:QUARTIC': [],
#  'CURVE:EXPONENT': [],
#  'CURVE:BICUBIC': [],
#  'CURVE:BIQUADRATIC': [],
#  'CURVE:QUADRATICLINEAR': [],
#  'CURVE:CUBICLINEAR': [],
#  'CURVE:TRIQUADRATIC': [],
#  'CURVE:FUNCTIONAL:PRESSUREDROP': [],
#  'CURVE:FANPRESSURERISE': [],
#  'CURVE:EXPONENTIALSKEWNORMAL': [],
#  'CURVE:SIGMOID': [],
#  'CURVE:RECTANGULARHYPERBOLA1': [],
#  'CURVE:RECTANGULARHYPERBOLA2': [],
#  'CURVE:EXPONENTIALDECAY': [],
#  'CURVE:DOUBLEEXPONENTIALDECAY': [],
#  'CURVE:CHILLERPARTLOADWITHLIFT': [],
#  'TABLE:INDEPENDENTVARIABLE': [],
#  'TABLE:INDEPENDENTVARIABLELIST': [],
#  'TABLE:LOOKUP': [],
#  'FLUIDPROPERTIES:NAME': [],
#  'FLUIDPROPERTIES:GLYCOLCONCENTRATION': [],
#  'FLUIDPROPERTIES:TEMPERATURES': [],
#  'FLUIDPROPERTIES:SATURATED': [],
#  'FLUIDPROPERTIES:SUPERHEATED': [],
#  'FLUIDPROPERTIES:CONCENTRATION': [],
#  'CURRENCYTYPE': [],
#  'COMPONENTCOST:ADJUSTMENTS': [],
#  'COMPONENTCOST:REFERENCE': [],
#  'COMPONENTCOST:LINEITEM': [],
#  'UTILITYCOST:TARIFF': [],
#  'UTILITYCOST:QUALIFY': [],
#  'UTILITYCOST:CHARGE:SIMPLE': [],
#  'UTILITYCOST:CHARGE:BLOCK': [],
#  'UTILITYCOST:RATCHET': [],
#  'UTILITYCOST:VARIABLE': [],
#  'UTILITYCOST:COMPUTATION': [],
#  'LIFECYCLECOST:PARAMETERS': [],
#  'LIFECYCLECOST:RECURRINGCOSTS': [],
#  'LIFECYCLECOST:NONRECURRINGCOST': [],
#  'LIFECYCLECOST:USEPRICEESCALATION': [],
#  'LIFECYCLECOST:USEADJUSTMENT': [],
#  'PARAMETRIC:SETVALUEFORRUN': [],
#  'PARAMETRIC:LOGIC': [],
#  'PARAMETRIC:RUNCONTROL': [],
#  'PARAMETRIC:FILENAMESUFFIX': [],
#  'OUTPUT:VARIABLEDICTIONARY': [
#  Output:VariableDictionary,
#      IDF;                      !- Key Field
#  ],
#  'OUTPUT:SURFACES:LIST': [
#  Output:Surfaces:List,
#      Details;                  !- Report Type
#  ],
#  'OUTPUT:SURFACES:DRAWING': [
#  Output:Surfaces:Drawing,
#      DXF,                      !- Report Type
#      Triangulate3DFace;        !- Report Specifications 1
#  ],
#  'OUTPUT:SCHEDULES': [],
#  'OUTPUT:CONSTRUCTIONS': [
#  Output:Constructions,
#      Constructions;            !- Details Type 1
#  ],
#  'OUTPUT:ENERGYMANAGEMENTSYSTEM': [
#  Output:EnergyManagementSystem,
#      Verbose,                  !- Actuator Availability Dictionary Reporting
#      None,                     !- Internal Variable Availability Dictionary Reporting
#      None;                     !- EMS Runtime Language Debug Output Level
#  ],
#  'OUTPUTCONTROL:SURFACECOLORSCHEME': [],
#  'OUTPUT:TABLE:SUMMARYREPORTS': [
#  Output:Table:SummaryReports,
#      AnnualBuildingUtilityPerformanceSummary,    !- Report 1 Name
#      DemandEndUseComponentsSummary,    !- Report 2 Name
#      SensibleHeatGainSummary,    !- Report 3 Name
#      InputVerificationandResultsSummary,    !- Report 4 Name
#      AdaptiveComfortSummary,    !- Report 5 Name
#      Standard62.1Summary,      !- Report 6 Name
#      ClimaticDataSummary,      !- Report 7 Name
#      EquipmentSummary,         !- Report 8 Name
#      EnvelopeSummary,          !- Report 9 Name
#      LightingSummary,          !- Report 10 Name
#      HVACSizingSummary,        !- Report 11 Name
#      SystemSummary,            !- Report 12 Name
#      ComponentSizingSummary,    !- Report 13 Name
#      OutdoorAirSummary,        !- Report 14 Name
#      ObjectCountSummary;       !- Report 15 Name
#  ],
#  'OUTPUT:TABLE:TIMEBINS': [],
#  'OUTPUT:TABLE:MONTHLY': [],
#  'OUTPUT:TABLE:ANNUAL': [],
#  'OUTPUTCONTROL:TABLE:STYLE': [
#  OutputControl:Table:Style,
#      TabAndHTML,               !- Column Separator
#      JtoKWH;                   !- Unit Conversion
#  ],
#  'OUTPUTCONTROL:REPORTINGTOLERANCES': [
#  OutputControl:ReportingTolerances,
#      1.11,                     !- Tolerance for Time Heating Setpoint Not Met
#      1.11;                     !- Tolerance for Time Cooling Setpoint Not Met
#  ],
#  'OUTPUT:VARIABLE': [
#  Output:Variable,
#      Block1B:Kitchen,          !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Kitchen,          !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Kitchen,          !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Kitchen,          !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom1,        !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom1,        !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom1,        !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom1,        !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room1,            !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room1,            !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room1,            !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room1,            !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Corridor,         !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Corridor,         !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Corridor,         !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Corridor,         !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom,         !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom,         !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom,         !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Bathroom,         !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Livingroom,       !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Livingroom,       !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Livingroom,       !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Livingroom,       !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room,             !- Key Value
#      Zone Mean Air Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room,             !- Key Value
#      Zone Mean Radiant Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room,             !- Key Value
#      Zone Operative Temperature,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      Block1B:Room,             !- Key Value
#      Zone Air Relative Humidity,    !- Variable Name
#      timestep,                 !- Reporting Frequency
#      On;                       !- Schedule Name
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Outdoor Air Drybulb Temperature,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Outdoor Air Dewpoint Temperature,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Wind Speed,          !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Wind Direction,      !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Direct Solar Radiation Rate per Area,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Diffuse Solar Radiation Rate per Area,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Solar Azimuth Angle,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Solar Altitude Angle,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Site Outdoor Air Barometric Pressure,    !- Variable Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Variable,
#      *,                        !- Key Value
#      Erl Shading Control Status,    !- Variable Name
#      Timestep;                 !- Reporting Frequency
#  ],
#  'OUTPUT:METER': [
#  Output:Meter,
#      Electricity:Facility,     !- Key Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Meter,
#      NaturalGas:Facility,      !- Key Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Meter,
#      InteriorEquipment:Electricity,    !- Key Name
#      timestep;                 !- Reporting Frequency
#  ,
#  Output:Meter,
#      InteriorLights:Electricity,    !- Key Name
#      timestep;                 !- Reporting Frequency
#  ],
#  'OUTPUT:METER:METERFILEONLY': [],
#  'OUTPUT:METER:CUMULATIVE': [],
#  'OUTPUT:METER:CUMULATIVE:METERFILEONLY': [],
#  'METER:CUSTOM': [],
#  'METER:CUSTOMDECREMENT': [],
#  'OUTPUTCONTROL:FILES': [],
#  'OUTPUT:JSON': [],
#  'OUTPUT:SQLITE': [],
#  'OUTPUT:ENVIRONMENTALIMPACTFACTORS': [
#  Output:EnvironmentalImpactFactors,
#      Hourly;                   !- Reporting Frequency
#  ,
#  Output:EnvironmentalImpactFactors,
#      Daily;                    !- Reporting Frequency
#  ,
#  Output:EnvironmentalImpactFactors,
#      Monthly;                  !- Reporting Frequency
#  ,
#  Output:EnvironmentalImpactFactors,
#      RunPeriod;                !- Reporting Frequency
#  ,
#  Output:EnvironmentalImpactFactors,
#      Timestep;                 !- Reporting Frequency
#  ],
#  'ENVIRONMENTALIMPACTFACTORS': [
#  EnvironmentalImpactFactors,
#      0.3,                      !- District Heating Efficiency
#      3.0,                      !- District Cooling COP
#      0.25,                     !- Steam Conversion Efficiency
#      80.7272,                  !- Total Carbon Equivalent Emission Factor From N2O
#      6.2727,                   !- Total Carbon Equivalent Emission Factor From CH4
#      0.2727;                   !- Total Carbon Equivalent Emission Factor From CO2
#  ],
#  'FUELFACTORS': [],
#  'OUTPUT:DIAGNOSTICS': [
#  Output:Diagnostics,
#      DisplayAdvancedReportVariables;    !- Key 1
#  ],
#  'OUTPUT:DEBUGGINGDATA': [],
#  'OUTPUT:PREPROCESSORMESSAGE': [],
#  'PYTHONPLUGIN:SEARCHPATHS': [],
#  'PYTHONPLUGIN:INSTANCE': [],
#  'PYTHONPLUGIN:VARIABLES': [],
#  'PYTHONPLUGIN:TRENDVARIABLE': [],
#  'PYTHONPLUGIN:OUTPUTVARIABLE': []}

# %% [markdown]
# ## Parameters and Objectives
# We start by defining `Parameters` that govern how we would like to modify the building.
# Here they are the solar heat gain coefficient and the lighting power density.

# %%
roof_ins = FieldSelector(class_name='Material',
                         object_name='MW Glass Wool (rolls)_.1445',
                         field_name='Thickness')
roof_range = RangeParameter(min_val=0.1,max_val=0.8)

parameters = [Parameter(selector=roof_ins,
                                 value_descriptor=roof_range ,
                                 name='Roof Insulation')]

#ACH parameters selection
ventAchRange = RangeParameter(min_val = 0.0, max_val=6.0)

for ventAch in building.idfobjects["ZoneVentilation:DesignFlowRate"]:
    sel = FieldSelector(class_name = 'ZoneVentilation:DesignFlowRate', 
                        object_name = ventAch.Name, 
                        field_name = 'Air Changes per Hour')
    parameters.append(Parameter(selector=sel, 
                                         value_descriptors=ventAchRange, 
                                         name='Ventilation ACH'))
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:424: FutureWarning: Use value_descriptors instead of value_descriptor.
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:441: UserWarning: This parameter's descriptor is already named Ventilation ACH.The name used as an input (Ventilation ACH) will be discarded.
#   warnings.warn(

# %% [markdown]
# Now, we specify that we would like to optimize for electricity use of the entire facility. We then bundle all of this information together.

# %%
objectives = ["DistrictHeating:Facility"]
problem = EPProblem(parameters, objectives)

# %% [markdown]
# ## Sampling
#
# We need to generate samples on which to train a surrogate model.
# The `sampler` uses Latin Hypercube Sampling to distribute the samples in the design space defined by the `Parameters`.
# We can check how well distributed they are using `describe()`.

# %%
inputs = sampling.dist_sampler(sampling.lhs, problem, 20)
inputs.describe()  # properties of the sample set
# Out:
#        Roof Insulation  Ventilation ACH
# count        20.000000        20.000000
# mean          0.453459         3.000367
# std           0.208696         1.779235
# min           0.112047         0.042300
# 25%           0.266874         1.653174
# 50%           0.456362         3.033809
# 75%           0.613670         4.377913
# max           0.779072         5.731280

# %% [markdown]
# ## Evaluator
# We now define and run the Evaluator, which will run the EnergyPlus instances with the different inputs generated in the previous cell.

# %%
evaluator = EvaluatorEP(problem, building)
train = evaluator.df_apply(inputs, keep_input=True,processes=4)
train.head()  # first 5 lines
# Out:
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:24
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:24
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up

# %% [markdown]
# We can save results at this point:

# %%
train.to_pickle("samples.p")

# %% [markdown]
# And load them again later:

# %%
train = pd.read_pickle("samples.p")

# %% [markdown]
# ## Exploring the training data
# Let's look at the correlation amongst the inputs and the output using a built-in [Seaborn](http://seaborn.pydata.org/) plot:

# %%
g = sns.pairplot(train)

# %% [markdown]
# Here's a plot of the _design space_ defined by the samples.

# %%
x, y,obj = problem.names()
train.plot.hexbin(x=x, y=y, C=obj, cmap="plasma", sharex=False, gridsize=50)

# %%
problem.names()

# %% [markdown]
# ## Fitting a surrogate model
#
# Now we can train the model using a ScikitLearn pipeline:

# %%
train

# %%
model = pipeline.make_pipeline(StandardScaler(), linear_model.LinearRegression())
model.fit(train[[x, y]].values, train[obj].values)

# %% [markdown]
# ## Running the surrogate model
#
# We can query the model at a specific point in the design space:

# %%
model.predict([[0.2, 0.25]])

# %% [markdown]
# Or for a `dataframe` made from a `dictionary` of points:

# %%
points = pd.DataFrame(data={"Thikness": [0, 1], "WWR": [8, 12]})
model.predict(points)

# %% [markdown]
# Next we define a function for querying the surrogate model across the domain at a given density, and plot the result.

# %%
def run_model(model, density):
    p1 = problem.inputs[0].value_descriptor
    a = np.linspace(p1.min, p1.max, density)
    p2 = problem.inputs[1].value_descriptor
    b = np.linspace(p2.min, p2.max, density)
    plot_data = pd.DataFrame(
        np.transpose([np.tile(a, len(b)), np.repeat(b, len(a))]),
        columns=problem.names("inputs"),
    )
    return pd.concat([plot_data, pd.Series(model.predict(plot_data))], axis=1)


density = 200
df = run_model(model, density)
df.plot.hexbin(x=x, y=y, C=0, cmap="plasma", gridsize=density, sharex=False)

# %% [markdown]
# ## Interactive surrogate
# Finally we make an interactive plot using `ipywidgets`, which executes the model every time a slider is moved.

# %%
problem.inputs

# %%
# get the min and max of the two variables
(min1, max1), (min2, max2) = (
    (float(p.value_descriptor.min), p.value_descriptor.max) for p in problem.inputs[:2]
)
# get the data to plot in the background
df = run_model(model, 100)

# define a wrapper to be queried by interact
def model_wrapper(v1, v2):
    df.plot.hexbin(
        x=x, y=y, C=0, cmap="plasma", gridsize=30, sharex=False
    )  # background plot
    x_lims = plt.xlim()
    y_lims = plt.ylim()
    plt.scatter(x=v1, y=v2)  # plot the marker
    plt.xlim((x_lims))
    plt.ylim((y_lims))

    value = (
        model.predict([[v1, v2]])[0] / 3.6e6
    )  # find the current value and convert to kWh
    output = (
        "Heating use = " + str(value.round()) + " kWh"
    )  # return the string to display
    return output


# make the interactive plot with two sliders
continuous_update = False
interact(
    model_wrapper,
    v1=FloatSlider(
        min=min1,
        max=max1,
        value=(min1 + max1) / 2,
        description="Thikness [m]",
        step=0.01,
        continuous_update=continuous_update,
    ),
    v2=FloatSlider(
        min=min2,
        max=max2,
        value=(min2 + max2) / 2,
        description="ACH",
        continuous_update=continuous_update,
    ),
)

# %% [markdown]
# # GP vs Nural Network vs TF

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
import warnings

# %%
roof_ins = FieldSelector(class_name='Material',
                         object_name='MW Glass Wool (rolls)_.1445',
                         field_name='Thickness')
wall_ins = FieldSelector(class_name='Material', 
                         object_name='EPS Expanded Polystyrene (Heavyweight)_.1', 
                         field_name='Thickness')

# %%
wall_range = RangeParameter(min_val=0.1,max_val=0.5)
roof_range = RangeParameter(min_val=0.1,max_val=0.8)

# %% [markdown]
# We can combine this with the `Selector` above to get a `Parameter`:

# %%
insulation_param = [Parameter(selector=wall_ins,
                                 value_descriptor=wall_range ,
                                 name='Wall Insulation'),
                   Parameter(selector=roof_ins,
                                 value_descriptor=roof_range ,
                                 name='Roof Insulation')]
print(insulation_param)
# Out:
# [Parameter(selector=FieldSelector(field_name='Thickness', class_name='Material', object_name='EPS Expanded Polystyrene (Heavyweight)_.1'), value_descriptors=[RangeParameter(min=0.1, max=0.5)]), Parameter(selector=FieldSelector(field_name='Thickness', class_name='Material', object_name='MW Glass Wool (rolls)_.1445'), value_descriptors=[RangeParameter(min=0.1, max=0.8)])]

# %%
#selection of windows parameters
win_arr = ['single_glazing','double_glazing','triple_glazing']
windowsTypes = CategoryParameter(win_arr)

windowsParameters = []

for fenestration in building.idfobjects["FenestrationSurface:Detailed"]:
     if fenestration.obj[2] == "Window":
        sel = FieldSelector(class_name ='FenestrationSurface:Detailed', 
                            object_name = fenestration.Name, 
                            field_name='Construction Name' )
        windowsParameters.append(Parameter(selector=sel, 
                                           value_descriptors = windowsTypes, 
                                           name='Windows types'))
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:441: UserWarning: This parameter's descriptor is already named Windows types.The name used as an input (Windows types) will be discarded.
#   warnings.warn(

# %%
#ACH parameters selection
ventAchRange = RangeParameter(min_val = 0.0, max_val=6.0)

ventilationAchParam = []

for ventAch in building.idfobjects["ZoneVentilation:DesignFlowRate"]:
    sel = FieldSelector(class_name = 'ZoneVentilation:DesignFlowRate', 
                        object_name = ventAch.Name, 
                        field_name = 'Air Changes per Hour')
    ventilationAchParam.append(Parameter(selector=sel, 
                                         value_descriptors=ventAchRange, 
                                         name='Ventilation ACH'))

# %%
TempShadingRange = RangeParameter(min_val = 18, max_val=30)
RadShadingRange = RangeParameter(min_val = 80, max_val=300)

setpointParams = []


for shadingControl in building.idfobjects["WindowShadingControl"]:
    sel = FieldSelector(class_name ='WindowShadingControl', object_name = shadingControl.Name, field_name='Setpoint' )
    sel2 = FieldSelector(class_name ='WindowShadingControl', object_name = shadingControl.Name, field_name='Setpoint 2' )
    setpointParams.append(Parameter(selector=sel, value_descriptor = TempShadingRange, name='Temp Setpoint shading'))
    setpointParams.append(Parameter(selector=sel2, value_descriptor = RadShadingRange, name='Rad Setpoint shading'))
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:441: UserWarning: This parameter's descriptor is already named Temp Setpoint shading.The name used as an input (Temp Setpoint shading) will be discarded.
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:441: UserWarning: This parameter's descriptor is already named Rad Setpoint shading.The name used as an input (Rad Setpoint shading) will be discarded.
#   warnings.warn(

# %%
lights_selector = FieldSelector(class_name='Lights', object_name='*', field_name='Watts per Zone Floor Area')

# %%
single_digit_integers = CategoryParameter(options=range(8,13))

# %%
lights_param =     Parameter(
        lights_selector,
        value_descriptor=single_digit_integers ,
        name="Lights Watts/Area",
    )

# %%
parameters = insulation_param + windowsParameters + [lights_param] + ventilationAchParam + setpointParams

# %%
objectives = ['Electricity:Facility','DistrictHeating:Facility','DistrictCooling:Facility'] # these get made into `MeterReader` or `VariableReader`

problem=EPProblem(parameters, objectives) # problem = parameters + objectives

# %%
samples = sampling.dist_sampler(sampling.lhs, problem, num_samples=40)
samples
# Out:
#     Wall Insulation  Roof Insulation   Windows types  Lights Watts/Area  \
# 0          0.300910         0.525084  double_glazing                 12
# 1          0.220243         0.754615  double_glazing                 11
# 2          0.296049         0.133330  single_glazing                  8
# 3          0.144529         0.242549  single_glazing                 11
# 4          0.335825         0.360026  double_glazing                  8
# 5          0.168190         0.623997  single_glazing                  9
# 6          0.329609         0.169956  single_glazing                  9
# 7          0.428350         0.415633  triple_glazing                 11
# 8          0.249620         0.732538  double_glazing                  8
# 9          0.194796         0.488122  triple_glazing                  9
# 10         0.363120         0.109366  double_glazing                  9
# 11         0.439344         0.380847  double_glazing                 10
# 12         0.454973         0.726362  triple_glazing                 10
# 13         0.472099         0.333055  triple_glazing                  9
# 14         0.484417         0.586937  single_glazing                 10
# 15         0.250515         0.691564  single_glazing                  8
# 16         0.112215         0.596453  triple_glazing                 11
# 17         0.342635         0.662874  double_glazing                  8
# 18         0.153895         0.630567  double_glazing                  9
# 19         0.441462         0.179245  triple_glazing                 12
# 20         0.137898         0.297589  single_glazing                 10
# 21         0.260694         0.188839  double_glazing                  9
# 22         0.385877         0.798054  single_glazing                  8
# 23         0.208638         0.219318  single_glazing                 10
# 24         0.469777         0.564776  triple_glazing                  8
# 25         0.418744         0.506493  triple_glazing                 12
# 26         0.350834         0.650435  triple_glazing                 12
# 27         0.288967         0.413524  double_glazing                 10
# 28         0.217745         0.284888  triple_glazing                 10
# 29         0.374154         0.448530  double_glazing                  8
# 30         0.394936         0.476600  double_glazing                 12
# 31         0.102963         0.456892  single_glazing                  9
# 32         0.176752         0.363576  single_glazing                 11
# 33         0.314239         0.775499  triple_glazing                 11
# 34         0.185590         0.271832  triple_glazing                 10
# 35         0.127021         0.709997  triple_glazing                 12
# 36         0.271093         0.148322  double_glazing                 11
# 37         0.235828         0.552475  single_glazing                 11
# 38         0.491524         0.239963  double_glazing                 12
# 39         0.406086         0.319400  single_glazing                 12
#
#     Ventilation ACH  Temp Setpoint shading  Rad Setpoint shading
# 0          4.870119              19.406877            267.723659
# 1          3.658748              18.348763            109.110888
# 2          1.852341              23.546265            197.084067
# 3          4.514362              28.689822            298.441091
# 4          5.214205              20.291087            216.441144
# 5          4.688349              18.751272            117.887172
# 6          1.726154              23.912096            174.385536
# 7          4.076786              29.691274            162.019927
# 8          0.043564              28.206087             97.905789
# 9          1.247175              26.085382            125.126724
# 10         3.063205              29.122404            230.044675
# 11         5.492841              24.396686            246.091932
# 12         2.056076              20.056597            294.274182
# 13         3.308323              26.100989            105.947505
# 14         3.922157              25.613540            188.556190
# 15         3.507736              21.295888            224.268327
# 16         0.297445              27.051891            181.822597
# 17         1.125960              19.579621            234.021035
# 18         2.460439              25.335364            280.781084
# 19         1.520655              26.506785            264.553578
# 20         0.427630              22.075489            156.321028
# 21         0.900890              19.093891            162.871386
# 22         5.266018              21.854101            140.616071
# 23         2.871519              29.012573            240.744859
# 24         4.955342              29.984924            275.658164
# 25         0.893027              22.257177            150.989247
# 26         5.663727              25.152386            206.988264
# 27         4.449084              28.084138             89.067042
# 28         3.799961              18.075072            137.204918
# 29         4.268399              24.010428            118.960457
# 30         2.367158              20.662217            130.725937
# 31         2.105069              23.016694            254.369265
# 32         2.697754              21.383294            258.228916
# 33         3.244097              27.757949            286.472210
# 34         5.779705              20.955199            205.656754
# 35         0.596567              24.672090             93.816327
# 36         0.655133              26.978003            192.631179
# 37         1.496383              27.323276            172.972738
# 38         5.950703              22.697143            219.622918
# 39         2.849761              23.217258             80.483372

# %%
evaluator = EvaluatorEP(problem, 
                        building, 
                        out_dir='outputdir', 
                        err_dir='outputdir',
                        epw_file='/home/ict4bd/ITA_Torino.160590_IWEC.epw',
                        progress_bar=True)
try:
    sim_samples=pd.read_csv('surrogate_simple_simulation_40.csv',index_col=0)
except:    
    sim_samples = evaluator.df_apply(samples,
                             keep_input=True, 
                             #keep_dirs=True, 
                             processes=4)  # flag keep_dirs to True to save all ouput
    sim_samples.to_csv('surrogate_simple_simulation_40.csv')
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/evaluator.py:672: FutureWarning: epw_file has been deprecated and will be removed in the future. Use epw instead.
#   warn(
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Updating Shadowing Calculations, Start Date=01/21/2017
# Initializing HVAC
# Warming up
# Updating Detailed Daylighting Factors, Start Date=01/21
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Warming up
# Updating Detailed Daylighting Factors, Start Date=03/22
# Warming up
# Warming up
# Warming up
# Warming up
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Warming up {2}
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Updating Shadowing Calculations, Start Date=03/02/2017
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Updating Detailed Daylighting Factors, Start Date=03/02
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Updating Shadowing Calculations, Start Date=01/21/2017
# Beginning Primary Simulation
# Updating Detailed Daylighting Factors, Start Date=01/21
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Warming up {7}
# Warming up {8}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Updating Shadowing Calculations, Start Date=01/21/2017
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=01/21
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Updating Shadowing Calculations, Start Date=04/11/2017
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Updating Shadowing Calculations, Start Date=10/28/2017
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=10/28
# Updating Shadowing Calculations, Start Date=08/29/2017
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Updating Detailed Daylighting Factors, Start Date=08/29
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  9.68sec
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# EnergyPlus Completed Successfully.
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Updating Shadowing Calculations, Start Date=09/18/2017
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 10.20sec
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# EnergyPlus Completed Successfully.
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# EnergyPlus Completed Successfully.
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 11.29sec
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Completed Successfully.
# EnergyPlus Run Time=00hr 00min 10.87sec
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Warming up {6}
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up {7}
# Warming up
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Updating Shadowing Calculations, Start Date=05/01/2017
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Updating Detailed Daylighting Factors, Start Date=05/01
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Updating Shadowing Calculations, Start Date=04/11/2017
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Warming up
# Updating Detailed Daylighting Factors, Start Date=04/11
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Updating Shadowing Calculations, Start Date=09/18/2017
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Updating Shadowing Calculations, Start Date=05/01/2017
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=05/01
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Updating Shadowing Calculations, Start Date=12/27/2017
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 10.74sec
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# EnergyPlus Completed Successfully.
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Updating Shadowing Calculations, Start Date=10/28/2017
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 10.92sec
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# EnergyPlus Completed Successfully.
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# EnergyPlus Run Time=00hr 00min 11.32sec
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  9.78sec
# EnergyPlus Completed Successfully.
# EnergyPlus Completed Successfully.
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:25
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# ...
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 10.25sec
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# EnergyPlus Completed Successfully.
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min 10.65sec
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:28
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Updating Shadowing Calculations, Start Date=10/08/2017
# Initializing HVAC
# Updating Detailed Daylighting Factors, Start Date=10/08
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Warming up {5}
# Warming up {6}
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Warming up {7}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# EnergyPlus Completed Successfully.
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  9.10sec
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  7.25sec
# EnergyPlus Completed Successfully.
# EnergyPlus Starting
# EnergyPlus, Version 9.6.0-f420c06a69, YMD=2022.09.01 21:28
# Initializing Response Factors
# Calculating CTFs for "GROUNDFLOOR"
# Calculating CTFs for "ROOF"
# Calculating CTFs for "PARTITION"
# Calculating CTFs for "PARTITION_REV"
# Calculating CTFs for "INSIDEDOOR"
# Calculating CTFs for "EXTERNALWALLBO.287"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=07/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 SUMMER DESIGN DAY LUG
# Warming up
# Calculating Detailed Daylighting Factors, Start Date=01/15
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 WINTER DESIGN DAY
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Could not find platform independent libraries <prefix>
# Could not find platform dependent libraries <exec_prefix>
# Consider setting $PYTHONHOME to <prefix>[:<exec_prefix>]
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Calculating Detailed Daylighting Factors, Start Date=01/01
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Warming up {7}
# Warming up {8}
# Starting Simulation at 01/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=01/21/2017
# Updating Detailed Daylighting Factors, Start Date=01/21
# Continuing Simulation at 01/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=02/10/2017
# Updating Detailed Daylighting Factors, Start Date=02/10
# Continuing Simulation at 02/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/02/2017
# Updating Detailed Daylighting Factors, Start Date=03/02
# Continuing Simulation at 03/02/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=03/22/2017
# Updating Detailed Daylighting Factors, Start Date=03/22
# Continuing Simulation at 03/22/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=04/11/2017
# Updating Detailed Daylighting Factors, Start Date=04/11
# Continuing Simulation at 04/11/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/01/2017
# Updating Detailed Daylighting Factors, Start Date=05/01
# Continuing Simulation at 05/01/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=05/21/2017
# Updating Detailed Daylighting Factors, Start Date=05/21
# Continuing Simulation at 05/21/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/10/2017
# Updating Detailed Daylighting Factors, Start Date=06/10
# Continuing Simulation at 06/10/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=06/30/2017
# Updating Detailed Daylighting Factors, Start Date=06/30
# Continuing Simulation at 06/30/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=07/20/2017
# Updating Detailed Daylighting Factors, Start Date=07/20
# Continuing Simulation at 07/20/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/09/2017
# Updating Detailed Daylighting Factors, Start Date=08/09
# Continuing Simulation at 08/09/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=08/29/2017
# Updating Detailed Daylighting Factors, Start Date=08/29
# Continuing Simulation at 08/29/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=09/18/2017
# Updating Detailed Daylighting Factors, Start Date=09/18
# Continuing Simulation at 09/18/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/08/2017
# Updating Detailed Daylighting Factors, Start Date=10/08
# Continuing Simulation at 10/08/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=10/28/2017
# Updating Detailed Daylighting Factors, Start Date=10/28
# Continuing Simulation at 10/28/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=11/17/2017
# Updating Detailed Daylighting Factors, Start Date=11/17
# Continuing Simulation at 11/17/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/07/2017
# Updating Detailed Daylighting Factors, Start Date=12/07
# Continuing Simulation at 12/07/2017 for YEAR_SIMULATION
# Updating Shadowing Calculations, Start Date=12/27/2017
# Updating Detailed Daylighting Factors, Start Date=12/27
# Continuing Simulation at 12/27/2017 for YEAR_SIMULATION
# Writing tabular output file results using tab format.
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  5.70sec
# EnergyPlus Completed Successfully.

# %%
sim_samples.columns
# Out:
# Index(['Wall Insulation', 'Roof Insulation', 'Windows types',
#        'Lights Watts/Area', 'Ventilation ACH', 'Temp Setpoint shading',
#        'Rad Setpoint shading', 'Electricity:Facility',
#        'DistrictHeating:Facility', 'DistrictCooling:Facility'],
#       dtype='object')

# %%
#remove inputs
features= list(samples.columns)
outputs = sim_samples.drop(features, axis=1)
#outputs

# %%
#remove outputs and windows types shading
samples = sim_samples.drop(['Electricity:Facility', 'DistrictHeating:Facility', 'DistrictCooling:Facility'], axis=1)
#samples

# %%
for i,win in enumerate(win_arr):
    samples['Windows types'] = samples['Windows types'].replace(win,i+1)

# %%
samples
# Out:
#     Wall Insulation  Roof Insulation  Windows types  Lights Watts/Area  \
# 0          0.300910         0.525084              2                 12
# 1          0.220243         0.754615              2                 11
# 2          0.296049         0.133330              1                  8
# 3          0.144529         0.242549              1                 11
# 4          0.335825         0.360026              2                  8
# 5          0.168190         0.623997              1                  9
# 6          0.329609         0.169956              1                  9
# 7          0.428350         0.415633              3                 11
# 8          0.249620         0.732538              2                  8
# 9          0.194796         0.488122              3                  9
# 10         0.363120         0.109366              2                  9
# 11         0.439344         0.380847              2                 10
# 12         0.454973         0.726362              3                 10
# 13         0.472099         0.333055              3                  9
# 14         0.484417         0.586937              1                 10
# 15         0.250515         0.691564              1                  8
# 16         0.112215         0.596453              3                 11
# 17         0.342635         0.662874              2                  8
# 18         0.153895         0.630567              2                  9
# 19         0.441462         0.179245              3                 12
# 20         0.137898         0.297589              1                 10
# 21         0.260694         0.188839              2                  9
# 22         0.385877         0.798054              1                  8
# 23         0.208638         0.219318              1                 10
# 24         0.469777         0.564776              3                  8
# 25         0.418744         0.506493              3                 12
# 26         0.350834         0.650435              3                 12
# 27         0.288967         0.413524              2                 10
# 28         0.217745         0.284888              3                 10
# 29         0.374154         0.448530              2                  8
# 30         0.394936         0.476600              2                 12
# 31         0.102963         0.456892              1                  9
# 32         0.176752         0.363576              1                 11
# 33         0.314239         0.775499              3                 11
# 34         0.185590         0.271832              3                 10
# 35         0.127021         0.709997              3                 12
# 36         0.271093         0.148322              2                 11
# 37         0.235828         0.552475              1                 11
# 38         0.491524         0.239963              2                 12
# 39         0.406086         0.319400              1                 12
#
#     Ventilation ACH  Temp Setpoint shading  Rad Setpoint shading
# 0          4.870119              19.406877            267.723659
# 1          3.658748              18.348763            109.110888
# 2          1.852341              23.546265            197.084067
# 3          4.514362              28.689822            298.441091
# 4          5.214205              20.291087            216.441144
# 5          4.688349              18.751272            117.887172
# 6          1.726154              23.912096            174.385536
# 7          4.076786              29.691274            162.019927
# 8          0.043564              28.206087             97.905789
# 9          1.247175              26.085382            125.126724
# 10         3.063205              29.122404            230.044675
# 11         5.492841              24.396686            246.091932
# 12         2.056076              20.056597            294.274182
# 13         3.308323              26.100989            105.947505
# 14         3.922157              25.613540            188.556190
# 15         3.507736              21.295888            224.268327
# 16         0.297445              27.051891            181.822597
# 17         1.125960              19.579621            234.021035
# 18         2.460439              25.335364            280.781084
# 19         1.520655              26.506785            264.553578
# 20         0.427630              22.075489            156.321028
# 21         0.900890              19.093891            162.871386
# 22         5.266018              21.854101            140.616071
# 23         2.871519              29.012573            240.744859
# 24         4.955342              29.984924            275.658164
# 25         0.893027              22.257177            150.989247
# 26         5.663727              25.152386            206.988264
# 27         4.449084              28.084138             89.067042
# 28         3.799961              18.075072            137.204918
# 29         4.268399              24.010428            118.960457
# 30         2.367158              20.662217            130.725937
# 31         2.105069              23.016694            254.369265
# 32         2.697754              21.383294            258.228916
# 33         3.244097              27.757949            286.472210
# 34         5.779705              20.955199            205.656754
# 35         0.596567              24.672090             93.816327
# 36         0.655133              26.978003            192.631179
# 37         1.496383              27.323276            172.972738
# 38         5.950703              22.697143            219.622918
# 39         2.849761              23.217258             80.483372

# %% [markdown]
# ## Train-test split
#
# Next we split the data into a training set (80%) and a testing set (20%).

# %%
train_in, test_in, train_out, test_out = train_test_split(
    samples, outputs, test_size=0.2
)

# %% [markdown]
# ## Normalization of inputs

# %% [markdown]
# To ensure an equal weighting of inputs and outputs in the backpropagation algorithm fitting the neural network, we have to normalize the input values.
# For example window-to-wall ratio is in the range of 0 to 1 while the $W/$m^2$ are in a range of 10 to 15.
# Different options for normalization exist.
# Here we bring all features (input variables) to have zero mean and a standarddeviation of 1.
# Note that we fit the normalizer on training data only.

# %%
scaler = StandardScaler()
train_in_scale = scaler.fit_transform(X=train_in)
test_in_scale = scaler.fit_transform(X=test_in)

scaler_out = StandardScaler()
train_out_scale = scaler_out.fit_transform(X=train_out)
test_out_scale = scaler_out.fit_transform(X=test_out)

# %% [markdown]
# # Gaussian Process

# %% [markdown]
# ## Hyper-parameters

# %% [markdown]
# Before fitting the GP model we define the set of hyperparameters we want to optimize.
# Here we use \textit{3} folds in the k-fold cross validation scheme.
# We select a set of Kernel functions, which must fit the characteristics of a problem - details and examples may be found in the [Kernel cookbook](https://www.cs.toronto.edu/~duvenaud/cookbook/).
# Note that the parameters of the Kernel itself are [optimized during each model fitting run](https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.GaussianProcessRegressor.html).

# %%
hyperparameters = {
    "kernel": [
        None,
        1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-1, 10.0)),
        1.0 * RationalQuadratic(length_scale=1.0, alpha=0.5),
        # ConstantKernel(0.1, (0.01, 10.0))*(DotProduct(sigma_0=1.0, sigma_0_bounds=(0.1, 10.0))**2),
        1.0 * Matern(length_scale=1.0, length_scale_bounds=(1e-1, 10.0)),
    ]
}

folds = 3

# %% [markdown]
# ## Model fitting

# %% [markdown]
# Here we fit the model using these hyperparameters.

# %%
gp = GaussianProcessRegressor(normalize_y=True)

clf = GridSearchCV(gp, hyperparameters, cv=folds)

clf.fit(train_in_scale, train_out_scale)

best_gp = clf.best_estimator_

# %%
prediction = scaler_out.inverse_transform(best_gp.predict(test_in_scale))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from math import sqrt

# %%
mean_squared_error(prediction,test_out.values,multioutput='raw_values',squared=False)/test_out.mean()*100
# Out:
# Electricity:Facility        0.427944
# DistrictHeating:Facility    6.729975
# DistrictCooling:Facility    8.781624
# dtype: float64

# %%
mean_absolute_error(prediction,test_out.values,multioutput='raw_values')/test_out.mean()*100
# Out:
# Electricity:Facility        0.402529
# DistrictHeating:Facility    5.663706
# DistrictCooling:Facility    6.961304
# dtype: float64

# %% [markdown]
# ## Hyper-parameters

# %% [markdown]
# Before we start fitting the NN model we define the set of hyperparameters we want to analyse in our cross-validation to optimize the model.
# Here, we select the number of layers of the network as well as the regularization parameter alpha as parameter value.
# A larger number of layers and a lower value of the regularizer lead to higher variance of the network.
# This may lead to overfitting.
# The best selection may be found using an optimizer like Bayesian Optimization.
# In this example we use a simple grid search.

# %%
hyperparameters = {
    "hidden_layer_sizes": (
        (len(parameters) * 16,),
        (len(parameters) * 16, len(parameters) * 16),
    ),
    "alpha": [1, 10, 10 ** 3],
}

neural_net = MLPRegressor(max_iter=1000, early_stopping=False)
folds = 3

# %% [markdown]
# ## Model fitting

# %% [markdown]
# Here, we use the NN model from ScikitLearn.
# In a [different example](FitNNTF.ipynb) we use TensorFlow (with and without the Keras wrapper).

# %%
clf = GridSearchCV(neural_net, hyperparameters, cv=folds)
clf.fit(train_in_scale, train_out_scale)

nn_model = clf.best_estimator_

# %%
prediction = scaler_out.inverse_transform(nn_model.predict(test_in_scale))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from math import sqrt

# %%
mean_squared_error(prediction,test_out.values,multioutput='raw_values',squared=False)/test_out.mean()*100
# Out:
# Electricity:Facility        0.690845
# DistrictHeating:Facility    4.615703
# DistrictCooling:Facility    7.866354
# dtype: float64

# %%
mean_absolute_error(prediction,test_out.values,multioutput='raw_values')/test_out.mean()*100
# Out:
# Electricity:Facility        0.492668
# DistrictHeating:Facility    4.213185
# DistrictCooling:Facility    5.888650
# dtype: float64

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
def build_model():
    model = keras.Sequential(
        [
            layers.Input(shape=(train_in_scale.shape[1], )),
            layers.Dense(32, activation='relu'),
            layers.Dense(64, activation='relu'),
            layers.Dense(32, activation='relu'),
            layers.Dense(3),
        ]
    )

    optimizer = tf.keras.optimizers.Adam(0.001)

    model.compile(loss="mse", optimizer=optimizer, metrics=["mae", "mse"])
    return model

model = build_model()

model.summary()

EPOCHS = 1000

history = model.fit(
    train_in_scale,
    train_out_scale,
    epochs=EPOCHS,
    validation_split=0.2,
    verbose=0,
)
# Out:
# 2022-09-01 21:29:12.599981: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                256
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 4,547
# Trainable params: 4,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction = scaler_out.inverse_transform(model.predict(test_in_scale))

# %%
mean_squared_error(prediction,test_out.values,multioutput='raw_values',squared=False)/test_out.mean()*100
# Out:
# Electricity:Facility         2.741210
# DistrictHeating:Facility     5.480067
# DistrictCooling:Facility    15.139444
# dtype: float64

# %%
mean_absolute_error(prediction,test_out.values,multioutput='raw_values')/test_out.mean()*100
# Out:
# Electricity:Facility         2.427560
# DistrictHeating:Facility     4.644719
# DistrictCooling:Facility    11.059575
# dtype: float64

# %% [markdown]
# ## Surrogate Modelling Evaluator object
# We can wrap the fitted model in a BESOS `EvaluatorGeneric`.

# %%
#Selection of windows parameters
win_arr=[1,2,3]
windowsTypes = CategoryParameter(win_arr)

windowsParameters = []

for fenestration in building.idfobjects["FenestrationSurface:Detailed"]:
     if fenestration.obj[2] == "Window":
        sel = FieldSelector(class_name ='FenestrationSurface:Detailed', object_name = fenestration.Name, field_name='Construction Name' )
        windowsParameters.append(Parameter(selector=sel, value_descriptors = windowsTypes, name='Windows types'))
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/besos/parameters.py:441: UserWarning: This parameter's descriptor is already named Windows types.The name used as an input (Windows types) will be discarded.
#   warnings.warn(

# %%
parameters = insulation_param + windowsParameters + [lights_param]  + ventilationAchParam + setpointParams

# %%
#objectives and problem definition
objectives = ['Electricity:Facility','DistrictHeating:Facility','DistrictCooling:Facility']

problem=Problem(parameters, objectives)

# %%
#definition of the evaluation function
def evaluation_func(ind, scaler=scaler):
    ind = scaler.transform(X=[ind])
    return (scaler_out.inverse_transform(nn_model.predict(ind))[0]).tolist()

evaluator = EvaluatorGeneric(evaluation_func, problem)

# %%
from besos.optimizer import NSGAII

# %%
#running NSGA-II optimizator 
results = NSGAII(evaluator, evaluations=5000, population_size=10000)
# Out:
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/ict4bd/ict4bd/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
optres = results.loc[results["pareto-optimal"] == True, :]  # Get only the optimal results

# %%
#plotting results
plt.figure(figsize=(8, 6), dpi=80)
ax = plt.axes(projection='3d')



df = pd.DataFrame(optres, columns=features + objectives)

ax.plot3D(results["DistrictCooling:Facility"], results["DistrictHeating:Facility"], results["Electricity:Facility"], "x")  # Plot all results in the background as blue crosses
ax.plot3D(optres["DistrictCooling:Facility"], optres["DistrictHeating:Facility"], optres["Electricity:Facility"], "ro")  # Plot optimal results in red

ax.set_xlabel("Cooling demand")
ax.set_ylabel("Heating demand")
ax.set_zlabel("Electricity demand")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Electricity demand')

# %%
optres
# Out:
#       Wall Insulation  Roof Insulation  Windows types  Lights Watts/Area  \
# 50           0.404825         0.757377              2                  8
# 106          0.474462         0.611226              2                  8
# 164          0.447061         0.598658              3                  8
# 172          0.489388         0.720197              3                 10
# 505          0.454617         0.778882              3                  9
# ...               ...              ...            ...                ...
# 9657         0.456175         0.458591              2                  8
# 9658         0.477955         0.791981              1                  9
# 9782         0.472453         0.619187              2                  8
# 9872         0.397222         0.717129              2                  8
# 9884         0.496676         0.734529              1                 11
#
#       Ventilation ACH  Temp Setpoint shading  Rad Setpoint shading  \
# 50           5.165335              25.051311            143.163421
# 106          3.924077              18.042725            270.145675
# 164          4.410879              27.159519            210.068198
# 172          5.348360              25.679614            177.819812
# 505          3.012805              18.552187            264.702388
# ...               ...                    ...                   ...
# 9657         4.487989              27.948108            109.606332
# 9658         5.489133              24.418230            187.589765
# 9782         5.408835              21.451936            238.207660
# 9872         5.529087              26.381708            286.882159
# 9884         4.055939              25.708589            239.012082
#
#       Electricity:Facility  DistrictHeating:Facility  \
# 50            6.657769e+09              1.211457e+10
# 106           6.643567e+09              1.246905e+10
# 164           6.667119e+09              1.207254e+10
# 172           7.307016e+09              1.133592e+10
# 505           6.966747e+09              1.151616e+10
# ...                    ...                       ...
# 9657          6.629170e+09              1.284423e+10
# 9658          6.925052e+09              1.122035e+10
# 9782          6.654420e+09              1.237728e+10
# 9872          6.659673e+09              1.228214e+10
# 9884          7.554210e+09              1.104066e+10
#
#       DistrictCooling:Facility  violation  pareto-optimal
# 50                4.385778e+09          0            True
# 106               4.458175e+09          0            True
# 164               4.050947e+09          0            True
# 172               3.437164e+09          0            True
# 505               4.016593e+09          0            True
# ...                        ...        ...             ...
# 9657              5.332621e+09          0            True
# 9658              4.808097e+09          0            True
# 9782              4.017169e+09          0            True
# 9872              4.141233e+09          0            True
# 9884              5.824257e+09          0            True
#
# [113 rows x 12 columns]

# %%
_=sns.pairplot(optres,x_vars=samples.columns, y_vars=objectives, kind="scatter")
# Out:
# <img src="data:image/png;base64,..." width="1750">

# %%
df['Total'] = df['Electricity:Facility'] + df['DistrictHeating:Facility'] + df['DistrictCooling:Facility']
df['Dist'] = df.apply(lambda row : np.sqrt(pow(row["DistrictCooling:Facility"],2) + pow(row["DistrictHeating:Facility"],2) + pow(row["Electricity:Facility"],2)),axis=1)

df[df.Dist == df.Dist.min()]
# Out:
#       Wall Insulation  Roof Insulation  Windows types  Lights Watts/Area  \
# 5277         0.478689         0.764939              3                  9
#
#       Ventilation ACH  Temp Setpoint shading  Rad Setpoint shading  \
# 5277          5.26209              26.423978            205.646151
#
#       Electricity:Facility  DistrictHeating:Facility  \
# 5277          6.983524e+09              1.135855e+10
#
#       DistrictCooling:Facility         Total          Dist
# 5277              3.443645e+09  2.178572e+10  1.377117e+10

# %%
corr=optres.corr()

# %%
unuseful = ['violation','pareto-optimal']

# %%
corr.drop(objectives + unuseful, axis = 1, inplace = True)
corr.drop(features + unuseful, axis = 0 ,inplace = True)
corr
# Out:
#                           Wall Insulation  Roof Insulation  Windows types  \
# Electricity:Facility             0.115098         0.459146      -0.094615
# DistrictHeating:Facility        -0.192951        -0.806533       0.231866
# DistrictCooling:Facility         0.398364        -0.115217      -0.808725
#
#                           Lights Watts/Area  Ventilation ACH  \
# Electricity:Facility               0.997271         0.150306
# DistrictHeating:Facility          -0.703693         0.002417
# DistrictCooling:Facility           0.153514        -0.439318
#
#                           Temp Setpoint shading  Rad Setpoint shading
# Electricity:Facility                   0.320214              0.065777
# DistrictHeating:Facility              -0.193005             -0.061481
# DistrictCooling:Facility               0.333535             -0.354794

# %%
plt.figure(figsize = (13,10))
_ = sns.heatmap(corr,annot=True)
# Out:
# <img src="data:image/png;base64,..." width="1300">
